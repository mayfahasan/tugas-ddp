# %%
kendaraan1=["avanza", "mobil", "toyota", 1500]
print(kendaraan1)
print()

kendaraan=kendaraan1+['hitam', 250_000_000]
kendaraan1.remove("mobil")
print(kendaraan1)
print()


pesan="""
menu:
1. menghitung luas persegi
2. menghitung luas lingkaran
3. menghitung luas segitiga
pilih menu:
"""
pilihan= input(pesan)

match pilihan:
  case "1":
   print("anda memasukan angka 1 untuk menghitung luas persegi")
   sisi= int(input("masukan sisi:"))
   luas= sisi*sisi
   print("luas persegi dengan sisi", sisi, "adalah", luas)

  case "2":
   print("kamu memilih 2 untuk menghitung luas lingkaran")
   jari_jari= int(input("masukan jari_jari:"))
   luas= 3.14 * jari_jari **2
   print("luas lingkaran yang jari jari", jari_jari ,"adalah", luas)

  case "3":
   print("anda masukan angka 3 untuk menghitung luas segitiga")
   alas= int(input("masukan alas:"))
   tinggi= int(input("masukan tinggi:"))
   luas= 1/2*(alas*tinggi)
   print("luas segitiga dengan alas", alas,"dan tinggi", tinggi, "adalah", luas)
# Out:
# ['avanza', 'mobil', 'toyota', 1500]
#
# ['avanza', 'toyota', 1500]
#
#
# menu:
# 1. menghitung luas persegi
# 2. menghitung luas lingkaran
# 3. menghitung luas segitiga
# pilih menu:
# 3
# anda masukan angka 3 untuk menghitung luas segitiga
# masukan alas:6
# masukan tinggi:7
# luas segitiga dengan alas 6 dan tinggi 7 adalah 21.0
